# %%
def validate(data):
    is_sequence = isinstance(data, (list, tuple))
    return is_sequence

print(validate([1, 2, 3])) # True
print(validate((1, 2, 3))) # True
print(validate(3)) # False
# Out:
# True

# %%
medical_records = [
    {
        'patient_id': 'P1001',
        'age': 34,
        'gender': 'Female',
        'diagnosis': 'Hypertension',
        'medications': ['Lisinopril'],
        'last_visit_id': 'V2301'
    }
]
print(*medical_records[0])
# Out:
# patient_id age gender diagnosis medications last_visit_id

# %%
def sum(a, b, c):
    return a + b + c
nums = {'b': 4, 'a': 2, 'c': 1}

print(sum(**nums)) # 7
# Out:
# 7

# %%
constraints = {"patient_id" = patient_id}

# %%
print(isinstance(None, (int, None)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 print(isinstance(None, (int, None)))
#
# TypeError: isinstance() arg 2 must be a type, a tuple of types, or a union

# %%
medications = [9, 'Insulin']
lala = {'medications': isinstance(medications, list) and all([isinstance(i, str) for i in medications])}
print(lala)
# Out:
# {'medications': False}

# %%
lala = ["Hello", "kala", "KAKA"]
print(lala.lower())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 2
#       1 lala = ["Hello", "kala", "KAKA"]
# ----> 2 print(lala.lower())
#
# AttributeError: 'list' object has no attribute 'lower'

# %%
import pdb

def divide(a, b):
    pdb.set_trace()
    return a / b

print(divide(10, 2))
# Out:
# > /var/folders/jn/ktvmjzyd6yn8zmbnmgdstt780000gn/T/ipykernel_4345/1997667433.py(4)divide()
#       2
#       3 def divide(a, b):
# ----> 4     pdb.set_trace()
#       5     return a / b
#       6
#
# --KeyboardInterrupt--
#
# KeyboardInterrupt: Interrupted by user
# 5.0

# %%
try:
    x = 1 / 0
except ZeroDivisionError as e:
    print(f'Error occurred: {e}')
# Out:
# Error occurred

# %%
def get_setting(config: dict, key: str) -> str:
    if config is None:
        assert x >= 0, "x must be non-negative"
    try:
        return config[key]
    except KeyError:
        raise KeyError(f"Setting '{key}' not found") from None


config = {
    "host": "localhost",
    "port": "8080"
}

print(get_setting(3, "debug"))
# Raises: ValueError("Missing required setting: debug")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 15
#       7         raise KeyError(f"Setting '{key}' not found") from None
#      10 config = {
#      11     "host": "localhost",
#      12     "port": "8080"
#      13 }
# ---> 15 print(get_setting(3, "debug"))
#      16 # Raises: ValueError("Missing required setting: debug")
#
# Cell In[49], line 5, in get_setting(config, key)
#       3     raise
#       4 try:
# ----> 5     return config[key]
#       6 except KeyError:
#       7     raise KeyError(f"Setting '{key}' not found") from None
#
# TypeError: 'int' object is not subscriptable
