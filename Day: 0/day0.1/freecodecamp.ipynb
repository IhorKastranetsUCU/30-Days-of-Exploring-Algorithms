# %%
ages = [1, 3, 83, 23, 44, 23, 44]
del ages[2]
ages.pop(3)

people = {"Oleh": 28, "Dima": 19, "Taras": 44}
del people["Oleh"]


print(ages.index(44))
# Out:
# 4

# %%
def pin_extractor(poem):
    secret_code = ''
    lines = poem.split("\n")
    print(lines)


poem = """Stars and the moon
shine in the sky
white and bright
until the end of the night"""

pin_extractor(poem)
# Out:
# ['Stars and the moon', 'shine in the sky', 'white and bright', 'until the end of the night']

# %%
nums = [1, 2, 3, 4]
print(" ".join(nums))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 nums = [1, 2, 3, 4]
# ----> 2 print(" ".join(nums))
#
# TypeError: sequence item 0: expected str instance, int found

# %%
a = [1, 2, 3, [3, 2, 1]]
b = a
a.append(b)
print(a)
# Out:
# [1, 2, 3, [3, 2, 1], [...]]

# %%
import time

a = [i for i in range(1000000001)]

def evaluate_time(n):
    start = time.time()
    print(a[n])
    finish = time.time()
    return finish-start

print(evaluate_time(0))
print(evaluate_time(1000000000))
# Out:
# 0
# 0.0022132396697998047
# 1000000000
# 3.3855438232421875e-05

# %%
b = set(a)
print(b)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       1 def count_sort(list):
#       2     ordered = set(list)[2]
# ----> 4 count_sort([3, 2, 1 ,5, 6, 3, 2])
#
# Cell In[3], line 2, in count_sort(list)
#       1 def count_sort(list):
# ----> 2     ordered = set(list)[2]
#
# TypeError: 'set' object is not subscriptable
