# %%
from sympy import andre

print(1, 2, 4, 5)
# Out:
# 1 2 4 5

# %% [markdown]
# I didn't know that comma creates separator " " between values

# %%
print(type(None))
# Out:
# <class 'NoneType'>

# %% [markdown]
# Consider that `None` is a different class. I used to thing that it is subclass of integer numbers

# %%
print(type(range(5)))
# Out:
# <class 'range'>

# %% [markdown]
# It turn out that `range` is its own type

# %% [markdown]
# python is dynamically typed language which means the variables automatically assigned the correct data type

# %%
my_str = 'hello world'
title_case_my_str = my_str.title() # Returns a new string with the first letter of each word capitalized.
print(title_case_my_str)

# %%
False or True and print(4)
# Out:
# 4

# %%
a = 5   #101
b = 6   #110
a = a ^ b   #011
b = a ^ b   #101
a = a ^ b   #110
print(a, b)
# Out:
# 6 5

# %% [markdown]
# To correctly determine scope, Python follows the LEGB rule, which stands for the following:
# - Local scope (L): Variables defined in functions or classes.
# - Enclosing scope (E): Variables defined in enclosing or nested functions.
# - Global scope (G): Variables defined at the top level of the module or file.
# - Built-in scope (B): Reserved names in Python for predefined functions, modules, keywords, and objects.

# %%
def outer_func():
    msg = 'Hello there!'
    res = ""  # Declare res in the enclosing scope

    def inner_func():
        nonlocal res  # Allow modification of an enclosing variable
        res = 'How are you?'
        print(msg)  # Accessing msg from outer_func()

    inner_func()
    print(res)  # Now res is accessible and modified

outer_func()
# Out:
# Hello there!
# jj

# %%
my_var_1 = 7

def show_vars():
    global my_var_2
    my_var_2 = 10
    print(my_var_1)
    print(my_var_2)

show_vars() # 7 10

# my_var_2 is now a global variable and can be accessed anywhere in the program
print(my_var_2) # 10
# Out:
# 7
# 10
# 10

# %%
txt = "Hello Sam!"
# Create a table to replace 'S' with 'P' and 'm' with 'n'
x = "Sm"
y = "Pn"
mytable = str.maketrans(x, y)
print(mytable)
print(txt.translate(mytable))
# Out:
# {83: 80, 109: 110}
# Hello Pan!

# %%
def encode_message(message: str) -> str:
    nums = []
    for i in message:
        if i not in nums:
            nums.append(i)
    # Генеруємо достатньо символів для заміни
    replacements = ''.join([chr(65 + i) for i in range(len(nums))])  # A, B, C...
    mytable = str.maketrans(''.join(nums), replacements)
    return message.translate(mytable)

print(encode_message("УсімПривівзйвт"))
# Out:
# ABCDEFGHCHIJHK

# %% [markdown]
# ![finished](img.png)
